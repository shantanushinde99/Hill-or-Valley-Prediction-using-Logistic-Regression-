# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Hill Valley Dataset.csv')
data.head(5)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0     39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1      1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2  68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3  44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4      5.70      5.40      5.28      5.38      5.27      5.61      6.00
#
#          V8        V9       V10  ...       V92       V93       V94       V95  \
# 0     39.53     38.81     38.79  ...     36.62     36.92     38.80     38.52
# 1      1.70      1.75      1.78  ...      1.80      1.79      1.77      1.74
# 2  73268.61  74465.84  72503.37  ...  73438.88  71053.35  71112.62  74916.48
# 3  37668.32  40980.89  38466.15  ...  42625.67  40684.20  46960.73  44546.80
# 4      5.38      5.34      5.87  ...      5.17      5.67      5.60      5.94
#
#         V96       V97       V98       V99      V100  Class
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Columns: 101 entries, V1 to Class
# dtypes: float64(100), int64(1)
# memory usage: 956.5 KB

# %%
data.describe()
# Out:
#                   V1             V2             V3             V4  \
# count    1212.000000    1212.000000    1212.000000    1212.000000
# mean     8169.091881    8144.306262    8192.653738    8176.868738
# std     17974.950461   17881.049734   18087.938901   17991.903982
# min         0.920000       0.900000       0.850000       0.890000
# 25%        19.602500      19.595000      18.925000      19.277500
# 50%       301.425000     295.205000     297.260000     299.720000
# 75%      5358.795000    5417.847500    5393.367500    5388.482500
# max    117807.870000  108896.480000  119031.350000  110212.590000
#
#                   V5             V6             V7             V8  \
# count    1212.000000    1212.000000    1212.000000    1212.000000
# mean     8128.297211    8173.030008    8188.582748    8183.641543
# std     17846.757963   17927.114105   18029.562695   18048.582159
# min         0.880000       0.860000       0.870000       0.650000
# ...

# %%
data.isnull().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
#         ..
# V97      0
# V98      0
# V99      0
# V100     0
# Class    0
# Length: 101, dtype: int64

# %%
data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        ...
#        'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'V100',
#        'Class'],
#       dtype='object', length=101)

# %%
features = [f'V{i}' for i in range(1,101)]
print(features)
# Out:
# ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41', 'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51', 'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'V61', 'V62', 'V63', 'V64', 'V65', 'V66', 'V67', 'V68', 'V69', 'V70', 'V71', 'V72', 'V73', 'V74', 'V75', 'V76', 'V77', 'V78', 'V79', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V86', 'V87', 'V88', 'V89', 'V90', 'V91', 'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'V100']

# %%
feature = data[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41', 'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51', 'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'V61', 'V62', 'V63', 'V64', 'V65', 'V66', 'V67', 'V68', 'V69', 'V70', 'V71', 'V72', 'V73', 'V74', 'V75', 'V76', 'V77', 'V78', 'V79', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V86', 'V87', 'V88', 'V89', 'V90', 'V91', 'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'V100']]
target = data["Class"]

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(feature,target , test_size=0.3,stratify=target , random_state=41)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((848, 100), (364, 100), (848,), (364,))

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=5000)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 96.7032967032967

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Assuming 'y_test' and 'y_pred' are already available from the Logistic Regression model

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create a figure and axis
fig, ax = plt.subplots()
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap="Blues", ax=ax)

# Add custom text annotations for the values (TP, TN, FP, FN)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        # Display the value inside each square
        ax.text(j, i, f"{cm[i, j]}", ha="center", va="center", color="black")

# Add custom labels for the confusion matrix, shifted to the extreme left corner of each cell
ax.text(-0.3, 0, 'TN', ha='left', va='top', fontsize=12, color='black')
ax.text(-0.3, 1, 'FP', ha='left', va='top', fontsize=12, color='black')
ax.text(1.3, 0, 'FN', ha='left', va='top', fontsize=12, color='black')
ax.text(1.3, 1, 'TP', ha='left', va='top', fontsize=12, color='black')

# Add title and show plot
plt.title("Confusion Matrix for Logistic Regression with TP/TN/FP/FN Labels")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       182
#            1       0.96      0.98      0.97       182
#
#     accuracy                           0.97       364
#    macro avg       0.97      0.97      0.97       364
# weighted avg       0.97      0.97      0.97       364

# %%
import numpy as np
import pandas as pd

# Define the number of features (100 features: V1 to V100)
num_features = 100

# Define the number of random samples you want to generate (e.g., x samples)
num_samples = 20

# Generate random data for features V1 to V100 (random values between -10 and 10)
random_inputs = np.random.uniform(low=-10, high=10, size=(num_samples, num_features))

# Convert the generated random data into a pandas DataFrame
# The column names should match your feature names (V1 to V100)
random_inputs_df = pd.DataFrame(random_inputs, columns=[f'V{i}' for i in range(1, 101)])

# Print the randomly generated inputs
print("Generated Random Inputs for Prediction (V1 to V100):")
print(random_inputs_df)

# Predicting the class for these randomly generated inputs using the trained model
random_predictions = model.predict(random_inputs_df)

# Map prediction 0 -> Hill, 1 -> Valley
prediction_labels = ['Hill' if pred == 0 else 'Valley' for pred in random_predictions]

# Print the predictions for the random inputs
print("\nPredictions for the Random Inputs (Sample -> Prediction):")
for i, label in enumerate(prediction_labels):
    print(f"Sample {i+1}: {label}")
# Out:
# Generated Random Inputs for Prediction (V1 to V100):
#           V1        V2        V3        V4        V5        V6        V7  \
# 0   4.568179  0.847653  6.420742  0.828553  9.952878  0.078150  1.343948
# 1  -0.050376 -2.432862  7.683264 -2.775990  7.922513 -4.125061  4.660331
# 2   1.545826  2.095989 -6.452693  7.160609 -1.415042 -3.676503  4.926410
# 3   1.041726 -2.082026  4.458008  1.204360  9.524005 -5.665969 -5.714557
# 4   9.014245  4.538012  1.956392  1.429359  6.315421 -8.054494 -1.231377
# 5   7.694759  8.305705 -4.326830 -4.517482 -9.579431 -9.765960 -6.651847
# 6  -0.746170 -7.978127 -2.433332  4.177136  8.168908  1.392734  6.135324
# 7   1.223781 -3.984174 -1.452326  0.703379 -0.516012 -6.512593  0.989974
# 8  -2.771741  7.250888 -9.462343 -0.892139 -6.600340 -9.308850  2.533533
# 9   1.622572  6.341692 -2.117590  3.593953 -6.459908 -1.227425  8.674358
# 10 -7.541213 -6.541428 -0.717760  6.547722 -2.296992  8.741060  9.619189
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Generate synthetic data for a single feature V1 (for simplicity)
# We are creating a linear relationship between feature V1 and the target (binary: Hill = 0, Valley = 1)
np.random.seed(42)

# Creating random values for V1 between -10 and 10
V1 = np.linspace(-10, 10, 1000)

# Simulating a binary target that corresponds to V1 (for simplicity, you can use actual data here)
# Using a simple threshold function to simulate "Hill" and "Valley"
y = (V1 > 0).astype(int)  # Class 0 for Hill if V1 <= 0, and class 1 for Valley if V1 > 0

# Reshaping V1 to be a 2D array (as required by sklearn)
X = V1.reshape(-1, 1)

# Fit Logistic Regression Model
model = LogisticRegression()
model.fit(X, y)

# Predict probabilities using the logistic regression model (probability of class 1)
probabilities = model.predict_proba(X)[:, 1]

# Plotting the S-curve (sigmoid curve)
plt.figure(figsize=(8, 6))
plt.plot(V1, probabilities, color='blue', lw=2)
plt.title("S-Curve for Logistic Regression (Prediction Probability)")
plt.xlabel("Feature V1")
plt.ylabel("Predicted Probability of Valley (Class 1)")
plt.grid(True)
plt.axvline(x=0, color='k', linestyle='--', lw=1)  # Add a vertical line where V1 = 0 (decision boundary)
plt.show()
